# %% [markdown]
# Make sure that
# * sudo pip3 install requests
# * sudo pip3 install bs4
# * sudo pip3 install pandas
#
# were ran before executing the code beneath

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux ×86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.106 Safari/537.36'}
page =  "https://www.transfermarkt.co.uk/fc-arsenal/startseite/verein/467"
pageTree = requests.get(page, headers=headers)
pageSoup = BeautifulSoup(pageTree. content, 'html.parser')

# %%
club_id = page.split("/")[-1]
print(club_id)
# Out:
# 467

# %%
pageSoup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <script data-description="sourcepoint stub code" type="text/javascript">
#     !function () { var e = function () { var e, t = "__tcfapiLocator", a = [], n = window; for (; n;) { try { if (n.frames[t]) { e = n; break } } catch (e) { } if (n === window.top) break; n = n.parent } e || (!function e() { var a = n.document, r = !!n.frames[t]; if (!r) if (a.body) { var i = a.createElement("iframe"); i.style.cssText = "display:none", i.name = t, a.body.appendChild(i) } else setTimeout(e, 5); return !r }(), n.__tcfapi = function () { for (var e, t = arguments.length, n = new Array(t), r = 0; r < t; r++)n[r] = arguments[r]; if (!n.length) return a; if ("setGdprApplies" === n[0]) n.length > 3 && 2 === parseInt(n[1], 10) && "boolean" == typeof n[3] && (e = n[3], "function" == typeof n[2] && n[2]("set", !0)); else if ("ping" === n[0]) { var i = { gdprApplies: e, cmpLoaded: !1, cmpStatus: "stub" }; "function" == typeof n[2] && n[2](i) } else a.push(n) }, n.addEventListener("message", (function (e) { var t = "string" == typeof e.data, a = {}; try { a = t ? JSON.parse(e.data) : e.data } catch (e) { } var n = a.__tcfapiCall; n && window.__tcfapi(n.command, n.version, (function (a, r) { var i = { __tcfapiReturn: { returnValue: a, success: r, callId: n.callId } }; t && (i = JSON.stringify(i)), e.source.postMessage(i, "*") }), n.parameter) }), !1)) }; "undefined" != typeof module ? module.exports = e : e() }();
# </script>
# <script data-description="sourcepoint configuration">
# window._sp_ = {
#     config: {"accountId":1254,"propertyId":7426,"gdpr":{"consentLanguage":"en","targetingParams":{"acps":"false"}},"baseEndpoint":"https://cdn.privacy-mgmt.com","isSPA":true,"cpPropertyId":"32280c37"}}
# </script>
# <script async="" src="https://cdn.privacy-mgmt.com/wrapperMessagingWithoutDetection.js"></script>
# <script data-description="contentpass integration" type="text/javascript">
#     (function() {
#         var cpBaseUrl = 'https://cp.transfermarkt.co.uk';
#         var cpController = cpBaseUrl + '/now.js';
#         var cpPropertyId = '32280c37';
#
#         !function(C,o,n,t,P,a,s){C['CPObject']=n;C[n]||(C[n]=function(){
#         (C[n].q=C[n].q||[]).push(arguments)});C[n].l=+new Date;a=o.createElement(t);
#         s=o.getElementsByTagName(t)[0];a.src=P;s.parentNode.insertBefore(a,s)}
#         (window,document,'cp','script',cpController);
#
#         !function(C,o,n,t,P){if(!C[n].patched){cp('extension','authenticate');P=C[n].q.push;
#         C[n].q.push=function(a){if(a[0]==='authenticate'){if((o['cookie']||'').indexOf('_cpauthhint=')===-1&&
#         !(C['localStorage']||{})['_cpuser']&&C.location.href.toLowerCase().indexOf('cpauthenticated')===-1){
#         t={isLoggedIn:function(){return false;},hasValidSubscription:function(){return false;}};
#         (typeof a[1]==='function'&&a[1](null,t));C[n].afp=true;P.apply(C[n].q,[['authenticate',null]]);
#         return t;}}P.apply(C[n].q,[a]);}}}
#         (window,document,'cp',false);
#
#         cp('create', cpPropertyId, {
#         baseUrl: cpBaseUrl
#         });
#
#         cp('render', {
#         onFullConsent: function() {
#             console.log('[DEMO] onFullConsent');
#         }
#         })
#     })()
# </script>
# <script data-description="contentpass sourcepoint fast path" type="text/javascript">
# (function () {
#     cp('authenticate', function(err, user) {
#         if (err || (!user.isLoggedIn() && !user.hasValidSubscription())) {
#         console.log('[SPCP] Taking fast path');
#         (function spExecMsg() {
#             if (window._sp_ && window._sp_.executeMessaging) {
#             if (!window._sp_.config.isSPA) {
#                 console.warn('[SPCP] Sourcepoint not in SPA mode!');
#             } else if (window._sp_.version) {
#                 console.log('[SPCP] Sourcepoint already running');
#             } else {
#                 console.log('[SPCP] Starting Sourcepoint');
#                 window._sp_.executeMessaging();
#             }
#             } else {
#             console.log('[SPCP] Sourcepoint not loaded yet. Retrying.');
#             setTimeout(spExecMsg, 10);
#             }
#         })();
#         }
#     });
#     })();
# </script>
# <meta charset="utf-8"/>
# <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/favicon-16x16.png" rel="shortcut icon" sizes="16x16"/>
# <link href="/android-chrome-192x192.png" rel="shortcut icon" sizes="192x192"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0, user-scalable=no" name="viewport"/>
# <meta content="NEC Nijmegen,Netherlands" name="keywords"/>
# <meta content="All information about NEC Nijmegen (Eredivisie) ➤ current squad with market values ➤ transfers ➤ rumours ➤ player stats ➤ fixtures ➤ news" name="description"/>
# <meta content="article" property="og:type"/>
# <meta content="https://tmssl.akamaized.net/images/tm_logo.png" property="og:image"/>
# <meta content="" property="og:description"/>
# <meta content="NEC Nijmegen - Club profile " property="og:title"/>
# <meta content="https://www.transfermarkt.co.uk/fc-arsenal/startseite/verein/467" property="og:url"/>
# <link href="https://www.transfermarkt.de/fc-arsenal/startseite/verein/467" hreflang="de" rel="alternate">
# <link href="https://www.transfermarkt.de/fc-arsenal/startseite/verein/467" hreflang="de-LU" rel="alternate">
# <link href="https://www.transfermarkt.at/fc-arsenal/startseite/verein/467" hreflang="de-AT" rel="alternate"/>
# <link href="https://www.transfermarkt.ch/fc-arsenal/startseite/verein/467" hreflang="de-CH" rel="alternate"/>
# <link href="https://www.transfermarkt.com.tr/fc-arsenal/startseite/verein/467" hreflang="tr" rel="alternate"/>
# <link href="https://www.transfermarkt.it/fc-arsenal/startseite/verein/467" hreflang="it-CH" rel="alternate"/>
# <link href="https://www.transfermarkt.it/fc-arsenal/startseite/verein/467" hreflang="it" rel="alternate"/>
# <link href="https://www.transfermarkt.pl/fc-arsenal/startseite/verein/467" hreflang="pl" rel="alternate"/>
# <link href="https://www.transfermarkt.co.uk/fc-arsenal/startseite/verein/467" hreflang="en-GB" rel="alternate"/>
# <link href="https://www.transfermarkt.co.uk/fc-arsenal/startseite/verein/467" hreflang="en-IE" rel="alternate"/>
# <link href="https://www.transfermarkt.es/fc-arsenal/startseite/verein/467" hreflang="es" rel="alternate"/>
# <link href="https://www.transfermarkt.es/fc-arsenal/startseite/verein/467" hreflang="es-ES" rel="alternate"/>
# <link href="https://www.transfermarkt.es/fc-arsenal/startseite/verein/467" hreflang="es-CL" rel="alternate"/>
# <link href="https://www.transfermarkt.es/fc-arsenal/startseite/verein/467" hreflang="es-VE" rel="alternate"/>
# <link href="https://www.transfermarkt.es/fc-arsenal/startseite/verein/467" hreflang="es-EC" rel="alternate"/>
# <link href="https://www.transfermarkt.es/fc-arsenal/startseite/verein/467" hreflang="es-CU" rel="alternate"/>
# <link href="https://www.transfermarkt.nl/fc-arsenal/startseite/verein/467" hreflang="nl" rel="alternate"/>
# <link href="https://www.transfermarkt.pt/fc-arsenal/startseite/verein/467" hreflang="pt" rel="alternate"/>
# <link href="https://www.transfermarkt.world/fc-arsenal/startseite/verein/467" hreflang="ru" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/fc-arsenal/startseite/verein/467" hreflang="fr-CH" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/fc-arsenal/startseite/verein/467" hreflang="fr" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/fc-arsenal/startseite/verein/467" hreflang="fr-CA" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/fc-arsenal/startseite/verein/467" hreflang="fr-CI" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/fc-arsenal/startseite/verein/467" hreflang="fr-LU" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/fc-arsenal/startseite/verein/467" hreflang="fr-BE" rel="alternate"/>
# <link href="https://www.transfermarkt.com.br/fc-arsenal/startseite/verein/467" hreflang="pt-BR" rel="alternate"/>
# <link href="https://www.transfermarkt.us/fc-arsenal/startseite/verein/467" hreflang="en-US" rel="alternate"/>
# <link href="https://www.transfermarkt.us/fc-arsenal/startseite/verein/467" hreflang="en-CA" rel="alternate"/>
# <link href="https://www.transfermarkt.co.in/fc-arsenal/startseite/verein/467" hreflang="en-IN" rel="alternate"/>
# <link href="https://www.transfermarkt.co.za/fc-arsenal/startseite/verein/467" hreflang="en-ZA" rel="alternate"/>
# <link href="https://www.transfermarkt.com/fc-arsenal/startseite/verein/467" hreflang="x-default" rel="alternate"/>
# <link href="https://www.transfermarkt.com/fc-arsenal/startseite/verein/467" hreflang="en" rel="alternate"/>
# <link href="https://www.transfermarkt.be/fc-arsenal/startseite/verein/467" hreflang="nl-BE" rel="alternate"/>
# <link href="https://www.transfermarkt.ro/fc-arsenal/startseite/verein/467" hreflang="ro" rel="alternate"/>
# <link href="https://www.transfermarkt.gr/fc-arsenal/startseite/verein/467" hreflang="el-GR" rel="alternate"/>
# <link href="https://www.transfermarkt.co.kr/fc-arsenal/startseite/verein/467" hreflang="ko-KR" rel="alternate"/>
# <link href="https://www.transfermarkt.com.ar/fc-arsenal/startseite/verein/467" hreflang="es-AR" rel="alternate"/>
# <link href="https://www.transfermarkt.mx/fc-arsenal/startseite/verein/467" hreflang="es-MX" rel="alternate"/>
# <link href="https://www.transfermarkt.co/fc-arsenal/startseite/verein/467" hreflang="es-CO" rel="alternate"/>
# <link href="https://www.transfermarkt.pe/fc-arsenal/startseite/verein/467" hreflang="es-PE" rel="alternate"/>
# <link href="https://www.transfermarkt.my/fc-arsenal/startseite/verein/467" hreflang="ms" rel="alternate"/>
# <link href="https://www.transfermarkt.jp/fc-arsenal/startseite/verein/467" hreflang="ja" rel="alternate"/>
# <link href="https://www.transfermarkt.co.id/fc-arsenal/startseite/verein/467" hreflang="id" rel="alternate"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/menue.css?lm=1704965888" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/styles/tm-main.min.css?lm=1704965869" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/main_desktop.css?lm=1704965888" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/print.css?_sn=1?lm=1704965888" media="print" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/vereinsseite.css?lm=1704965888" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/spielbericht.css?lm=1704965887" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/statistiken.css?lm=1704965888" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/chosen.css?lm=1704965888" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/main.css?lm=1704965888" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/styles/tm-club-profile.min.css?lm=1704965869" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/vereinTopTransfers.css?lm=1704965888" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/aufstellung.css?lm=1704965888" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/beliebtheit.css?lm=1704965888" rel="stylesheet" type="text/css"/>
# <style type="text/css">
# /*<![CDATA[*/
# @keyframes heim {
#     0%   {width: 0%;}
#     100% {width: 0%}
# }
# @keyframes gast {
#     0%   {width: 0%;}
#     100% {width: 0%}
# }
# .fav-voting__home {
#     animation-name: heim;
#     animation-duration: 4s;
# }
# .fav-voting__visitor {
#     animation-name: gast;
#     animation-duration: 4s;
# }
# /*]]>*/
# </style>
# <script src="https://tmssl.akamaized.net/js/vendor/jquery.min.js?lm=1704965877" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/assets/b7c5571cf8957553f95f6d9069eaed67/jquery.ba-bbq.min.js?lm=1704965878" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/custom-elements/ce-competition-intersection-observer.js?lm=1704965877" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/main.js?lm=1704965877" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/chosen.ajaxaddition.jquery.js?lm=1704965877" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/functions.js?lm=1704965877" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/main_desktop.js?lm=1704965877" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/chosen.jquery.js?lm=1704965877" type="text/javascript"></script>
# <script type="text/javascript">
# /*<![CDATA[*/
# console.info("%c [TM-ADs] Initialize Ads on domain .uk (verein/startseite)", "background: #282828; color: #bada55")
# console.info("%c [TM-ADs] Tisoomi is active -> add Tisoomi script", "background: #282828; color: #bada55")
# console.info("%c [TM-ADs] Render slot ADTAG_CONTENT_BODY_1 () for footballco", "background: #282828; color: #bada55")
# console.info("%c [TM-ADs] Wrap ad container with Tisoomi for format ADTAG_CONTENT_BODY_1", "background: #282828; color: #bada55")
# console.info("%c [TM-ADs] Render slot ADTAG_CONTENT_BODY_2 () for footballco", "background: #282828; color: #bada55")
# console.info("%c [TM-ADs] Wrap ad container with Tisoomi for format ADTAG_CONTENT_BODY_2", "background: #282828; color: #bada55")
# console.info("%c [TM-ADs] Render slot rectangle1 () for footballco", "background: #282828; color: #bada55")
# console.info("%c [TM-ADs] Wrap ad container with Tisoomi for format rectangle1", "background: #282828; color: #bada55")
# console.info("%c [TM-ADs] Render slot rectangle2 () for footballco", "background: #282828; color: #bada55")
# console.info("%c [TM-ADs] Wrap ad container with Tisoomi for format rectangle2", "background: #282828; color: #bada55")
# console.info("%c [TM-ADs] Render slot skyscraper () for footballco", "background: #282828; color: #bada55")
# console.info("%c [TM-ADs] Wrap ad container with Tisoomi for format skyscraper", "background: #282828; color: #bada55")
# console.info("%c [TM-ADs] Render slot billboard () for footballco", "background: #282828; color: #bada55")
# console.info("%c [TM-ADs] Wrap ad container with Tisoomi for format billboard", "background: #282828; color: #bada55")
# console.info("%c [TM-ADs] Render slot fullsize_contentad () for footballco", "background: #282828; color: #bada55")
# console.info("%c [TM-ADs] Wrap ad container with Tisoomi for format fullsize_contentad", "background: #282828; color: #bada55")
#     var oddsServe = function(placement,competition,match,node) {
#         if (!node){
#             var s=document.readyState==='loading'?document.getElementsByTagName('script'):[];
#             node=s.length?s[s.length-1].parentNode:null;
#         }
#         oddsServe.queue.push({contentUnitId:placement,competition:competition,match:match,node:node});
#     }
#
#     oddsServe.onInit=function(callbacks){
#         if (typeof window.__tcfapi === 'function') {
#             __tcfapi('addEventListener', 2, function(tcdata, success) {
#                 let tcf20compatibleString;
#                 if(success) {
#                     if (tcdata.eventStatus === 'useractioncomplete') {
#                         tcf20compatibleString = tcdata.tcString;
#                     } else if (tcdata.eventStatus === 'tcloaded') {
#                         tcf20compatibleString = tcdata.tcString;
#                     }
#                     callbacks.setGdprOptions({
#                         gdpr:1,
#                         gdpr_pd:1,
#                         gdpr_consent:tcf20compatibleString,
#                     });
#                 }
#             });
#         } else {
#             console.warn('E2: __tcfapi not found');
#         }
#     };
#     oddsServe.options={gdpr_wait:true};
#     oddsServe.queue=[];
# console.info("%c [TM-ADs] Add adslot configuration for ADTAG_CONTENT_BODY_1 | ADTAG_CONTENT_BODY_2 | rectangle1 | rectangle2 | skyscraper | billboard | fullsize_contentad", "background: #282828; color: #bada55")
# console.info("%c [TM-ADs] Adslots without configuration: inreadSpecial | PerformPlayer | skyscraperbtf | richmedia", "background: #282828; color: #bada55")
# console.info("%c [TM-ADs] Register slots with JS vendor lib", "background: #282828; color: #bada55")
# console.info("%c [TM-ADs] Render ad slots js for footballco", "background: #282828; color: #bada55")
#
# console.info("%c [TM-ADs] skip external script https://lngtd.com/transfermarkt_homepage.js for footballco on wettbewerbe_team_rest", "background: #282828; color: #bada55")
# console.info("%c [TM-ADs] Added external ad script(s) for vendor footballco", "background: #282828; color: #bada55")
# /*]]>*/
# </script>
# <title>NEC Nijmegen - Club profile  | Transfermarkt</title>
# <link href="/apple-touch-icon-152x152.png" rel="apple-touch-icon-precomposed"/>
# <script type="text/javascript">
#    tmData = {
#        loggedIn : "0",
#        tmTraffic: "0",
#    };
# </script>
# <script>// Set to the same value as the web property used on the site
# 		var gaProperty = 'UA-3816204-13';
#
# 		// Disable tracking if the opt-out cookie exists.
# 		var disableStr = 'ga-disable-' + gaProperty;
# 		if (document.cookie.indexOf(disableStr + '=true') > -1) {
# 			window[disableStr] = true;
# 		}
#
# 		// Opt-out function
# 		function gaOptout() {
# 			document.cookie = disableStr + '=true; expires=Thu, 31 Dec 2099 23:59:59 UTC; path=/';
# 			window[disableStr] = true;
# 		}</script>
# <script>
# 	window.dataLayer = window.dataLayer || [];
# 	function gtag() { dataLayer.push(arguments); }
#    gtag('set', 'linker', { 'domains': [/^transfermarkt\.(com|de|nl|it|at|ch|es|fr|com\.tr|pt|tv|pl|co\.uk)$/]});
#    gtag('js', new Date());
#    gtag('set',
#   {
#     'custom_map': {
#                     'dimension1': 'loggedIn',
#                     'dimension2': 'tmTraffic'
#                 }
#   });
#         gtag('config', 'UA-3816204-13', {
#                 'anonymize_ip': true,
#                 'transport_type': 'beacon',
#                 'content_group1': 'statistik',
#                 'content_group2': 'verein',
#                 'content_group3': 'startseite',
#                 'content_group4': '467',
#                 'loggedIn': tmData.loggedIn,
#                 'tmTraffic': tmData.tmTraffic
#             });
#    function tmEvent(category, action, label) {
#                 if (typeof gtag !== 'function') {
#                     return;
#                 }
#                 gtag('event',
#                     action,
#                     {
#                         'event_category': category,
#                         'event_label': label
#                     }
#                 );
#             }
#
#             function tmTiming(value, name, event_category, event_label) {
#                 if (typeof gtag !== 'function') {
#                     return;
#                 }
#                 gtag('event', 'timing_complete', {
#                     name,
#                     value,
#                     event_category,
#                     event_label
#                 });
#             }
#
# 	</script> <script src="https://tmssl.akamaized.net//ads/ads.js" type="text/javascript"></script>
# <script type="text/javascript">
#         window.tmGaId = "UA-3816204-13";
#         function sendIvwData() {}
#     </script>
# <link href="https://www.transfermarkt.co.uk/nec-nijmegen/startseite/verein/467" rel="canonical"/> </link></link></head>
# <body class="" data-cmp-layer-id="910149" data-tm-tld="uk" itemscope="" itemtype="http://schema.org/WebPage">
# <tm-language-hint></tm-language-hint>
# <div id="main">
# <div class="werbung-skyscraper-container">
# <script type="text/javascript">//OrJs9s8("skyscraper")</script>
# <div class="werbung werbung-skyscraper">
# <div id="div-gpt-ad-skyscraper" style="min-width: 160px; min-height: 600px;">
# </div>
# </div>
# <span class="OrJs9s8_end"></span>
# </div>
# <div class="werbung-skyscraperbtf-container">
# </div>
# <header class="tm-header">
# <div class="tm-header__box">
# <a href="/">
# <img alt="Transfermarkt" class="icon-logo" height="62" src="https://tmsi.akamaized.net/head/transfermarkt_logo.svg" title="Transfermarkt" width="156"/>
# </a>
# <tm-domainswitcher open-list="false" tld="co.uk"></tm-domainswitcher>
# <div class="tm-header__social-box">
# <a class="header__social-link" href="https://www.facebook.com/transfermarkt.co.uk" onclick="tmEvent('SM-Icons_Header','click','Facebook');
# " target="_blank">
# <img class="header__icon" height="20" src="https://tmsi.akamaized.net/icons/socialMedia/fb_icon_hover.svg" width="20"/>
# </a>
# <a class="header__social-link header__social-link--twitter" href="http://twitter.com/TMuk_news" onclick="tmEvent('SM-Icons_Header','click','Twitter');
# " target="_blank">
# <img class="header__icon header__icon--twitter" height="20" src="https://tmsi.akamaized.net/icons/socialMedia/twitter.svg" width="20"/>
# </a>
# <a class="header__social-link" href="http://instagram.com/transfermarkt_official" onclick="tmEvent('SM-Icons_Header','click','Instagram');
# " target="_blank">
# <img class="header__icon" height="20" src="https://tmsi.akamaized.net/icons/socialMedia/instagram_icon_hover.svg" width="20"/>
# </a>
# <a class="header__social-link" href="/intern/rssguide" onclick="tmEvent('SM-Icons_Header','click','RSS');
# " target="_blank">
# <img class="header__icon" height="20" src="https://tmsi.akamaized.net/icons/socialMedia/rss_icon_hover.svg" width="20"/>
# </a>
# <a class="header__social-link" href="https://www.tiktok.com/@transfermarkt" onclick="tmEvent('SM-Icons_Header','click','Tiktok');
# " target="_blank">
# <img class="header__icon" height="20" src="https://tmsi.akamaized.net/icons/tiktokRebrush.svg" width="20"/>
# </a>
# </div>
# <div class="tm-header__input-wrapper" id="schnellsuche-platz">
# <form action="/schnellsuche/ergebnis/schnellsuche" class="tm-header__form" id="schnellsuche" name="schnellsuche">
# <input autocorrect="off" class="tm-header__input--search-field" name="query" onclick="" placeholder="Enter your search term" spellcheck="false" type="text" value=""/>
# <input alt="search" class="tm-header__input--search-send" type="submit" value=""/>
# </form>
# <a class="tm-header__search-detail" href="/detailsuche/spielerdetail/suche" id="detailsuche-head" title="to detailed player search">
# <img alt="search" class="tm-header__icon-detail-search" height="26" src="https://tmsi.akamaized.net/icons/search_icon_plus_blue_white.svg" width="26"/>
# </a>
# </div>
# </div>
# <nav class="main-navbar navihalter">
# <ul class="main-navbar__container megamenu_dark_bar megamenu_dark" itemscope="itemscope" itemtype="http://www.schema.org/SiteNavigationElement">
# <a class="sticky-logo hide-for-small" href="/">
# <span class="tm_svg" title="Transfermarkt"></span>
# </a>
# <li class="main-navbar__list" data-nav-group="news">
# <span class="main-navbar__list-title tm-main-nav-el" onclick="tmEvent('News','click','menu');
# ">
#             News        </span>
# <div class="main-navbar__drop-down">
# <img class="navigation-loading-spinner" height="40" src="https://tmsi.akamaized.net/icons/tm_spinner_inverted.min.svg" width="40">
# </img></div>
# <li class="main-navbar__list" data-nav-group="transfers">
# <span class="main-navbar__list-title tm-main-nav-el" onclick="tmEvent('Transfers &amp; Gerüchte','click','menu');
# ">
#             Transfers &amp; rumours        </span>
# <div class="main-navbar__drop-down">
# <img class="navigation-loading-spinner" height="40" src="https://tmsi.akamaized.net/icons/tm_spinner_inverted.min.svg" width="40">
# </img></div>
# <li class="main-navbar__list" data-nav-group="marktwerte">
# <span class="main-navbar__list-title tm-main-nav-el" onclick="tmEvent('Marktwerte','click','menu');
# ">
#             Market values        </span>
# <div class="main-navbar__drop-down">
# <img class="navigation-loading-spinner" height="40" src="https://tmsi.akamaized.net/icons/tm_spinner_inverted.min.svg" width="40">
# </img></div>
# <li class="main-navbar__list aktiv" data-nav-group="wettbewerbe">
# <span class="main-navbar__list-title tm-main-nav-el" onclick="tmEvent('Wettbewerbe','click','menu');
# ">
#             Competitions        </span>
# <div class="main-navbar__drop-down">
# <img class="navigation-loading-spinner" height="40" src="https://tmsi.akamaized.net/icons/tm_spinner_inverted.min.svg" width="40">
# </img></div>
# <li class="main-navbar__list" data-nav-group="foren">
# <span class="main-navbar__list-title tm-main-nav-el" onclick="tmEvent('Foren','click','menu');
# ">
#             Forums        </span>
# <div class="main-navbar__drop-down">
# <img class="navigation-loading-spinner" height="40" src="https://tmsi.akamaized.net/icons/tm_spinner_inverted.min.svg" width="40">
# </img></div>
# <li class="main-navbar__list" data-nav-group="meintm">
# <span class="main-navbar__list-title tm-main-nav-el" onclick="tmEvent('MeinTM','click','menu');
# ">
#             My TM        </span>
# <div class="main-navbar__drop-down">
# <img class="navigation-loading-spinner" height="40" src="https://tmsi.akamaized.net/icons/tm_spinner_inverted.min.svg" width="40">
# </img></div>
# <li class="main-navbar__list">
# <a class="main-navbar__list-title tm-main-nav-el live-navilink" href="/ticker/index/live" onclick="tmEvent('Live','click','menu');
# ">
#             Live                            <tm-live-match-counter auto-request="true" content='["Live maches", "Live matches"]'></tm-live-match-counter>
# </a>
# </li>
# </li></li></li></li></li></li></ul>
# <form action="/schnellsuche/ergebnis/schnellsuche" class="noclose sticky-suche" id="schnellsuche-sticky" name="schnellsuche">
# <input class="header-suche" name="query" onclick="" placeholder="Enter your search term" type="text"/>
# <input alt="search" class="header-suche-abschicken" src="https://tmssl.akamaized.net//images/suchicon.png" type="image"/>
# </form>
# <a class="header-suche-detailsuche" href="/detailsuche/spielerdetail/suche" id="detailsuche-head" title="to detailed player search">
# <span class="icon-detailsuche"></span>
# </a>
# <a href="#" id="arrow-up-xy">
# <svg enable-background="new 0 0 100 100" height="100px" id="Layer_1" style="fill: white; width: 20px; height: 20px;" version="1.1" viewbox="0 0 100 100" width="100px" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
# <g>
# <path d="M78.016,49.132L51.961,12.714c-0.471-0.66-1.233-1.049-2.043-1.051c-0.006,0-0.006,0-0.006,0
#                                 c-0.815,0.002-1.575,0.396-2.048,1.059L21.977,49.14c-0.546,0.767-0.616,1.776-0.183,2.612c0.426,0.835,1.292,1.361,2.236,1.361
#                                 h12.183l-0.001,32.709c0,1.39,1.125,2.515,2.516,2.515l22.541-0.001c1.389,0.001,2.515-1.124,2.516-2.517l0-32.705h12.187
#                                 c0.94,0,1.803-0.53,2.237-1.367C78.641,50.911,78.566,49.9,78.016,49.132z"></path>
# </g>
# </svg>
# </a>
# <div class="tm-login" id="login" onclick="tmEvent('login','click','sign_in_button');
# ">
# <svg class="tm-login__image" enable-background="new 0 0 100 100" fill="#FFF" height="100px" id="Layer_1" version="1.1" viewbox="0 0 100 100" width="100px" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
# <g>
# <path d="M80.161,60.441l-15.66-7.47l-6.622-3.159c2.892-1.822,5.241-4.634,6.778-8.022c1.22-2.69,1.946-5.734,1.946-8.99
#                 c0-1.827-0.29-3.562-0.694-5.236C63.94,19.453,57.605,13.477,50,13.477c-7.461,0-13.701,5.763-15.792,13.645
#                 c-0.482,1.808-0.815,3.688-0.815,5.68c0,3.459,0.808,6.684,2.181,9.489c1.587,3.254,3.94,5.937,6.804,7.662l-6.342,2.953
#                 l-16.168,7.53c-1.404,0.658-2.327,2.242-2.327,4.011v15.062v2.703c0,2.381,1.659,4.312,3.708,4.312h57.505
#                 c2.048,0,3.708-1.93,3.708-4.312v-2.703V64.446C82.46,62.683,81.552,61.114,80.161,60.441z"></path>
# </g>
# </svg>
# <span class="tm-login__cta">
#         Log in    </span>
# </div>
# </nav>
# <div class="quick-select-wrapper">
# <div class="ssc" id="quickselect-skeleton" style="height: 40px;">
# <div class="ssc-wrapper flex" style="height: 100%; padding: 0">
# <div class="ssc-square quickselect-element" style="width: 40px;"></div>
# <div class="ssc-square quickselect-element quickselect-selector" style="width: 171.06px;"></div>
# <div class="ssc-square quickselect-element quickselect-selector" style="width: 170.84px;"></div>
# <div class="ssc-square quickselect-element quickselect-selector" style="width: 138.03px;"></div>
# <div class="ssc-square quickselect-element quickselect-selector" style="width: 141.5px;"></div>
# </div>
# </div>
# <tm-quick-select-bar default-club="467" default-competition="NL1" default-country="122" default-player="" dropdown-visible="" translations='{"home":"Home","country":"Country","competition":"Competition","club":"Club","player":"Player","attack":"Striker","midfield":"Mittelfeld","defense":"Defender","goalkeeper":"Goalkeeper"}'>
# </tm-quick-select-bar>
# </div>
# <script type="text/javascript">//OrJs9s8("billboard")</script>
# <div class="werbung werbung-billboard">
# <div id="div-gpt-ad-top_banner" style="min-width: 728px; min-height: 90px;">
# </div>
# </div>
# <span class="OrJs9s8_end"></span>
# </header>
# <main>
# <tm-consent embed="" no-checkbox="" type="teads"></tm-consent><header class="data-header">
# <div class="data-header__headline-container">
# <h1 class="data-header__headline-wrapper data-header__headline-wrapper--oswald">
#             NEC Nijmegen        </h1>
# </div>
# <div class="data-header__badge-container">
# <a class="data-header__success-data" href="/nec-nijmegen/erfolge/verein/467" title="Dutch Second League champion">
# <img alt="Dutch Second League champion" class="data-header__success-image lazy lazy" data-src="https://tmssl.akamaized.net/images/erfolge/header/434.png?lm=1585559859" src="..." title="Dutch Second League champion">
# <span class="data-header__success-number">
#                         2                    </span>
# </img></a>
# </div>
# <div class="data-header__box--big">
# <a class="data-header__box__club-link" href="/eredivisie/startseite/wettbewerb/NL1">
# <img alt="Eredivisie" height="80" srcset="
#                                     https://tmssl.akamaized.net/images/logo/homepageNewsLogo80x80/nl1.png?lm=1674743474 1x,
#                                     https://tmssl.akamaized.net/images/logo/homepageWappen150x150/nl1.png?lm=1674743474 2x
#                                 " width="80"/>
# </a>
# <div class="data-header__club-info">
# <span class="data-header__club" itemprop="affiliation">
# <a href="/eredivisie/startseite/wettbewerb/NL1">
#                         Eredivisie                    </a>
# </span>
# <span class="data-header__label">
# <strong>League level:</strong> <span class="data-header__content">
# <a href="/eredivisie/startseite/wettbewerb/NL1">
# <img alt="Netherlands" class="flaggenrahmen vm lazy lazy" data-src="https://tmssl.akamaized.net/images/flagge/tiny/122.png?lm=1520611569" src="..." title="Netherlands"/>First Tier
#                                 </a>
# </span>
# </span>
# <span class="data-header__label">
#                             Table position:
#                             <span class="data-header__content">
# <a href="/eredivisie/tabelle/wettbewerb/NL1" title="League table">8</a>
# </span>
# </span>
# <span class="data-header__label">
#                             In league since:
#                             <span class="data-header__content">
# <a href="/nec-nijmegen/platzierungen/verein/467" title="">3 years</a>
# </span>
# </span>
# </div>
# </div>
# <div class="data-header__profile-container">
# <img alt="NEC Nijmegen" class="" src="https://tmssl.akamaized.net/images/wappen/head/467.png?lm=1460302949" title="NEC Nijmegen"/>
# </div>
# <div class="data-header__box--small">
# <a class="data-header__market-value-wrapper" href="/nec-nijmegen/kader/verein/467"><span class="waehrung">€</span>24.83<span class="waehrung">m</span> <p class="data-header__last-update">
#                 Total market value            </p>
# </a>
# </div>
# <div class="data-header__info-box">
# <div class="data-header__details">
# <ul class="data-header__items">
# <li class="data-header__label">
#                     Squad size:
#                     <span class="data-header__content" itemprop="dataItem">
#                         25                    </span>
# </li>
# <li class="data-header__label">
#                     Average age:
#                     <span class="data-header__content" itemprop="dataItem">
#                         25.0                    </span>
# </li>
# <li class="data-header__label">
#                     Foreigners:
#                     <span class="data-header__content" itemprop="dataItem">
# <a href="/nec-nijmegen/legionaere/verein/467">10</a>  <span class="tabellenplatz">40.0 %</span> </span>
# </li>
# </ul>
# <ul class="data-header__items">
# <li class="data-header__label">
#                         National team players:
#                         <span class="data-header__content" itemprop="dataItem">
# <a href="/nec-nijmegen/nationalspieler/verein/467">2</a> </span>
# </li>
# <li class="data-header__label">
#                         Stadium:
#                         <span class="data-header__content" itemprop="dataItem">
# <a href="/nec-nijmegen/stadion/verein/467" title="NEC Nijmegen">Goffertstadion</a>  <span class="tabellenplatz">12.500 Seats</span> </span>
# </li>
# <li class="data-header__label">
#                         Current transfer record:
#                         <span class="data-header__content" itemprop="dataItem">
# <span class="greentext">
# <a class="greentext" href="/nec-nijmegen/transfers/verein/467/saison_id/2023">+€2.68m</a> </span>
# </span></li>
# </ul>
# </div>
# </div>
# <div class="data-header__toggle">
# <div class="data-header__toggle-icon">+</div>
# <ul class="data-header__list-clubs">
# <li>
# <img alt="NEC Nijmegen" class="tiny_wappen" src="https://tmssl.akamaized.net/images/wappen/tiny/467.png?lm=1460302949" title="NEC Nijmegen"/><span><a href="/nec-nijmegen/startseite/verein/467" title="NEC Nijmegen">NEC Nijmegen</a></span> </li><li>
# <img alt="NEC Nijmegen U21" class="tiny_wappen" src="https://tmssl.akamaized.net/images/wappen/tiny/11154.png?lm=1581615542" title="NEC Nijmegen U21"/><span><a href="/nec-nijmegen-u21/startseite/verein/11154" title="NEC Nijmegen U21">NEC Nijmegen U21</a></span> </li><li>
# <img alt="NEC Nijmegen U19" class="tiny_wappen" src="https://tmssl.akamaized.net/images/wappen/tiny/7463.png?lm=1581615542" title="NEC Nijmegen U19"/><span><a href="/nec-nijmegen-u19/startseite/verein/7463" title="NEC Nijmegen U19">NEC Nijmegen U19</a></span> </li><li>
# <img alt="NEC Nijmegen Amateure U19" class="tiny_wappen" src="https://tmssl.akamaized.net/images/wappen/tiny/59433.png?lm=1581615542" title="NEC Nijmegen Amateure U19"/><span><a href="/nec-nijmegen-amateure-u19/startseite/verein/59433" title="NEC Nijmegen Amateure U19">NEC Nijmegen Amateure U19</a></span> </li><li>
# <img alt="NEC Nijmegen U18" class="tiny_wappen" src="https://tmssl.akamaized.net/images/wappen/tiny/79122.png?lm=1581615542" title="NEC Nijmegen U18"/><span><a href="/nec-nijmegen-u18/startseite/verein/79122" title="NEC Nijmegen U18">NEC Nijmegen U18</a></span> </li><li>
# <img alt="NEC Nijmegen U17" class="tiny_wappen" src="https://tmssl.akamaized.net/images/wappen/tiny/43843.png?lm=1581615543" title="NEC Nijmegen U17"/><span><a href="/nec-nijmegen-u17/startseite/verein/43843" title="NEC Nijmegen U17">NEC Nijmegen U17</a></span> </li><li>
# <img alt="NEC Nijmegen Amateure 2" class="tiny_wappen" src="https://tmssl.akamaized.net/images/wappen/tiny/71377.png?lm=1581615543" title="NEC Nijmegen Amateure 2"/><span><a href="/nec-nijmegen-amateure-2/startseite/verein/71377" title="NEC Nijmegen Amateure 2">NEC Nijmegen Amateure 2</a></span> </li><li>
# <img alt="NEC Nijmegen Amateurs" class="tiny_wappen" src="https://tmssl.akamaized.net/images/wappen/tiny/20330.png?lm=1581615542" title="NEC Nijmegen Amateurs"/><span><a href="/nec-nijmegen-amateure/startseite/verein/20330" title="NEC Nijmegen Amateurs">NEC Nijmegen Amateurs</a></span> </li><li>
# <img alt="NEC Nijmegen Amateurs Youth" class="tiny_wappen" src="https://tmssl.akamaized.net/images/wappen/tiny/79121.png?lm=1581615542" title="NEC Nijmegen Amateurs Youth"/><span><a href="/nec-nijmegen-amateure-jugend/startseite/verein/79121" title="NEC Nijmegen Amateurs Youth">NEC Nijmegen Amateurs Youth</a></span> </li><li>
# <img alt="NEC Nijmegen Youth" class="tiny_wappen" src="https://tmssl.akamaized.net/images/wappen/tiny/32800.png?lm=1581615543" title="NEC Nijmegen Youth"/><span><a href="/nec-nijmegen-jugend/startseite/verein/32800" title="NEC Nijmegen Youth">NEC Nijmegen Youth</a></span> </li> </ul>
# </div>
# </header>
# <script type="text/javascript">
#    const headerLinkList = document.querySelector('.data-header__toggle');
#     if (headerLinkList) {
#         headerLinkList.addEventListener('click', () => {
#             headerLinkList.classList.toggle('data-header__toggle--active');
#         })
#     };
# </script>
# <a class="db mt10" href="https://www.transfermarkt.co.uk/top-100-most-valuable-players-in-the-world-rice-enters-top-10-mbappe-drops-to-third/view/news/432111" onclick="tmEvent('banner', 'https://www.transfermarkt.co.uk/top-100-most-valuable-players-in-the-world-rice-enters-top-10-mbappe-drops-to-third/view/news/432111', 'd-day-banner');" target="_blank">
# <img alt="deadline-day banner" height="99" src="https://dzjovqk3zamsg.cloudfront.net/lr531nkk.jpg" width="1034"/>
# </a>
# <div class="row hide-on-print" data-action="startseite" data-controller="verein" data-id="467" data-path="fc-arsenal/startseite/verein/467" data-season="" id="subnavi">
# <div class="page_wrapper subnavi">
# <div class="large-12 columns">
# <div class="subnavi_box" id="subnavigation">
# <div class="submenu-text show-for-small">
# <a name="SubNavi" title="Navigation">
# <span>≡ Sub navigation</span>
# </a>
# </div>
# <nav>
# <ul id="submenu">
# <li class="show-for-small" id="close_submenu">
# <div id="submenu-icon">
# <span class="clicked"></span>
# <span class="clicked"></span>
# </div>
# <a>Close subnavigation</a>
# </li>
# <li class="first-button aktiv" data-nav-group="overview" id="overview">
# <a class="tm-subnav-item megamenu" href="/nec-nijmegen/startseite/verein/467/saison_id/2023" name="SubNavi" onclick="tmEvent('subnavigation_verein','click','uebersicht');
# ">Overview</a>
# </li>
# <li class="" data-nav-group="squad" id="squad">
# <a class="tm-subnav-item megamenu_drop" href="#subnavi" name="SubNavi" onclick="tmEvent('subnavigation_verein','click','kader');
# ">Squad</a>
# <div class="dropdown_fullwidth" title=""><div><img class="navigation-loading-spinner" height="40" src="https://tmsi.akamaized.net/icons/tm_spinner_inverted.min.svg" width="40"/></div></div> </li>
# <li class="" data-nav-group="fixtures" id="fixtures">
# <a class="tm-subnav-item megamenu_drop" href="#subnavi" name="SubNavi" onclick="tmEvent('subnavigation_verein','click','spielplan');
# ">Fixtures</a>
# <div class="dropdown_fullwidth" title=""><div><img class="navigation-loading-spinner" height="40" src="https://tmsi.akamaized.net/icons/tm_spinner_inverted.min.svg" width="40"/></div></div> </li>
# <li class="" data-nav-group="transfers-amp-rumours" id="transfers-amp-rumours">
# <a class="tm-subnav-item megamenu_drop" href="#subnavi" name="SubNavi" onclick="tmEvent('subnavigation_verein','click','transfers-amp-geruchte');
# ">Transfers &amp; rumours</a>
# <div class="dropdown_fullwidth" title=""><div><img class="navigation-loading-spinner" height="40" src="https://tmsi.akamaized.net/icons/tm_spinner_inverted.min.svg" width="40"/></div></div> </li>
# <li class="" data-nav-group="information-amp-facts" id="information-amp-facts">
# <a class="tm-subnav-item megamenu_drop" href="#subnavi" name="SubNavi" onclick="tmEvent('subnavigation_verein','click','daten_und_fakten');
# ">Information &amp; facts</a>
# <div class="dropdown_fullwidth" title=""><div><img class="navigation-loading-spinner" height="40" src="https://tmsi.akamaized.net/icons/tm_spinner_inverted.min.svg" width="40"/></div></div> </li>
# <li class="" data-nav-group="stadium" id="stadium">
# <a class="tm-subnav-item megamenu_drop" href="#subnavi" name="SubNavi" onclick="tmEvent('subnavigation_verein','click','stadion');
# ">Stadium</a>
# <div class="dropdown_fullwidth" title=""><div><img class="navigation-loading-spinner" height="40" src="https://tmsi.akamaized.net/icons/tm_spinner_inverted.min.svg" width="40"/></div></div> </li>
# <li class="" data-nav-group="history" id="history">
# <a class="tm-subnav-item megamenu_drop" href="#subnavi" name="SubNavi" onclick="tmEvent('subnavigation_verein','click','historie');
# ">History</a>
# <div class="dropdown_fullwidth" title=""><div><img class="navigation-loading-spinner" height="40" src="https://tmsi.akamaized.net/icons/tm_spinner_inverted.min.svg" width="40"/></div></div> </li>
# <li class="" data-nav-group="news" id="news">
# <a class="tm-subnav-item megamenu" href="/nec-nijmegen/news/verein/467" name="SubNavi" onclick="tmEvent('subnavigation_verein','click','news');
# ">News</a>
# </li>
# <li class="subnavi-edit" data-nav-group="subnavi-edit" id="subnavi-edit">
# <a class="tm-subnav-item megamenu_drop" href="#subnavi" name="SubNavi" onclick="tmEvent('subnavigation_verein','click','edit');
# "></a>
# <div class="dropdown_fullwidth gasthinweis" title="Log in or register now"><div><img class="navigation-loading-spinner" height="40" src="https://tmsi.akamaized.net/icons/tm_spinner_inverted.min.svg" width="40"/></div></div> </li>
# </ul>
# </nav>
# </div>
# </div>
# </div>
# </div>
# <script>
#         var stickySubTop = $('#subnavigation').offset().top;
#         stickySubTop = stickySubTop - 60;
#         var main = $("#main");
#         $(document).ready(function() {
#             $(window).on('scroll load', function() {
#                 if (!main.hasClass("stickySubnavigation")) {
#                     stickySubTop = $('#subnavigation').offset().top;
#                 }
#                 if ($(window).scrollTop() > stickySubTop) {
#                     main.addClass("stickySubnavigation");
#                 } else {
#                     main.removeClass("stickySubnavigation");
#                 }
#             });
#         });
#     </script>
# <style>
#         .forum-anchor {
#             margin-top: -80px;
#         }
#     </style>
# <div class="row vereinsstartseite" itemscope="" itemtype="http://schema.org/SportsTeam">
# <div class="large-8 columns">
# <div class="box">
# <h2 class="content-box-headline">
#                         Squad NEC Nijmegen
#                                         </h2>
# <div id="statistik-infoblock">
# <div class="content">
# <form action="/nec-nijmegen/kader/verein/467/plus/0/galerie/0" method="get"> <div class="row">
# <div class="large-12 columns">
# <table class="auflistung">
# <tbody>
# <tr>
# <td>
#                                                         Filter by season                                                    </td>
# <td>
# <div class="inline-select">
# <select class="chzn-select" data-placeholder="Filter by season" name="saison_id" tabindex="0">
# <option selected="selected" value="2023">23/24                                                                    </option>
# <option value="2022">22/23                                                                    </option>
# <option value="2021">21/22                                                                    </option>
# <option value="2020">20/21                                                                    </option>
# <option value="2019">19/20                                                                    </option>
# <option value="2018">18/19                                                                    </option>
# <option value="2017">17/18                                                                    </option>
# <option value="2016">16/17                                                                    </option>
# <option value="2015">15/16                                                                    </option>
# <option value="2014">14/15                                                                    </option>
# <option value="2013">13/14                                                                    </option>
# <option value="2012">12/13                                                                    </option>
# <option value="2011">11/12                                                                    </option>
# <option value="2010">10/11                                                                    </option>
# <option value="2009">09/10                                                                    </option>
# <option value="2008">08/09                                                                    </option>
# <option value="2007">07/08                                                                    </option>
# <option value="2006">06/07                                                                    </option>
# <option value="2005">05/06                                                                    </option>
# <option value="2004">04/05                                                                    </option>
# <option value="2003">03/04                                                                    </option>
# <option value="2002">02/03                                                                    </option>
# <option value="2001">01/02                                                                    </option>
# <option value="2000">00/01                                                                    </option>
# <option value="1999">99/00                                                                    </option>
# <option value="1998">98/99                                                                    </option>
# <option value="1997">97/98                                                                    </option>
# <option value="1996">96/97                                                                    </option>
# <option value="1995">95/96                                                                    </option>
# <option value="1994">94/95                                                                    </option>
# <option value="1993">93/94                                                                    </option>
# <option value="1992">92/93                                                                    </option>
# <option value="1991">91/92                                                                    </option>
# <option value="1990">90/91                                                                    </option>
# <option value="1989">89/90                                                                    </option>
# <option value="1988">88/89                                                                    </option>
# <option value="1987">87/88                                                                    </option>
# <option value="1986">86/87                                                                    </option>
# <option value="1985">85/86                                                                    </option>
# <option value="1984">84/85                                                                    </option>
# <option value="1983">83/84                                                                    </option>
# <option value="1982">82/83                                                                    </option>
# <option value="1981">81/82                                                                    </option>
# <option value="1980">80/81                                                                    </option>
# <option value="1979">79/80                                                                    </option>
# <option value="1978">78/79                                                                    </option>
# <option value="1977">77/78                                                                    </option>
# <option value="1976">76/77                                                                    </option>
# <option value="1975">75/76                                                                    </option>
# <option value="1974">74/75                                                                    </option>
# <option value="1973">73/74                                                                    </option>
# <option value="1972">72/73                                                                    </option>
# ...
# var s=[Mt("kwwsv=22zzz1wudqvihupdunw1fr1xn2lpdjh2[HtepU73Jf|JsXyZg;33xXtPKko4yzh8pn[}YON|oS<t2"+t.ftshde01Rnd+"NKNtZWG4I}xjf[uFmOJ|;R6MMHEZQFW5[\\jwI<YNKnmLSrQ1jli",-3),Mt("kwwsv=22zzz1wudqvihupdunw1fr1xn2lpdjh2XtV;xwYLJELtj6|WhpQmq5zToYtNiHkhe7w3}rR|VkJX2"+t.ftshde01Rnd+"PNYZOk6z5UW5k]e4;FQ\\ioMOyGW{m3vSPoJ4mntLnSh;ZNs1jli",-3),Mt("kwwsv=22zzz1wudqvihupdunw1fr1xn2lpdjh2TXYout;:4f<fi{833<HTZLvhFs{JhQOze[\\Mt6gG;5Kf2"+t.ftshde01Rnd+"FFHUVusNlUeNjO\\uKkhsRQI\\:TwkpO|{U;JJW6vMO[fZ\\N|1jli",-3),Mt("kwwsv=22zzz1wudqvihupdunw1fr1xn2lpdjh2Z}Tym7wjQ}y9[}fquRp9SKJ5y5SIWXh\\N\\kTLu;4QwvS2"+t.ftshde01Rnd+"NTGSHI|yGv|fMGv;5s<7iOlMmLyfZ6MIq}IEOhixEwEjxIX1jli",-3),Mt("kwwsv=22zzz1wudqvihupdunw1fr1xn2lpdjh2Ng5ElIIvK:jyqX6wX:TvVQ}YLqVW9R[<rFo5jkRp[N;y2"+t.ftshde01Rnd+"\\HLHsOp|l;4rTEHltFfvK}QxNr{gNG6MuKKUTZjPsM8Ht:y1jli",-3),Mt("kwwsv=22zzz1wudqvihupdunw1fr1xn2lpdjh2RMw7VoxLOf6[fKVtXpS;n8HkhHwp\\N4w;8otxtrlX[7E2"+t.ftshde01Rnd+"KV\\;rs\\M4sKGpl|6rpfpJV\\TslWKtHQPPWQTK66|zYy|Ktv1jli",-3)],o=[Mt("kwwsv=22zzz1wudqvihupdunw1fr1xn2lpdjh2766r|;tpSkL[\\<XPE4wmxgvV[oT:nwhlt<y}i\\|lxorM2"+t.ftshde01Rnd+"V\\N;;|Kktv:Y[N\\7OxxE{Y}g}{X}NTwZM:R9Z7L9VhqRixs1jli",-3),Mt("kwwsv=22zzz1wudqvihupdunw1fr1xn2lpdjh2l6WmU;[8qjj<8Ftfx\\6h8Uh5n<Q{jroFU:3VfjH:JVTt2"+t.ftshde01Rnd+"\\ROl]pv<H3HE5<xoo8}]yK8JSFgrUu<nNHN\\jPUJZ}5yup61jli",-3),Mt("kwwsv=22zzz1wudqvihupdunw1fr1xn2lpdjh27onMOvO}ypmzUImYxhWvm8xNjGMuiJY;g8[Q:eyQ7y[32"+t.ftshde01Rnd+"EW\\M|<peMeXKNsp[s{5sQJ:Rgrj[3tNUq<Ujf98F]PzKe<}1jli",-3),Mt("kwwsv=22zzz1wudqvihupdunw1fr1xn2lpdjh2mjzTuoYrmWw;:wqIqSMQn:ism;zUn[KqRwu[<[qzsLlv2"+t.ftshde01Rnd+"]K[ytzGNV6:\\i68kt9HpFym]QqI8}3ZnlItQ]8km}r<;Uwm1jli",-3),Mt("kwwsv=22zzz1wudqvihupdunw1fr1xn2lpdjh2seftm]L|Kn:rW9lEuvJ]9[u[wO9v8pn5|O8[<ftkP{y{2"+t.ftshde01Rnd+"\\VOFHfERussNIHysoLo3Wq}|N4{i5f|Qs5fEL:H[oViS6\\q1jli",-3),Mt("kwwsv=22zzz1wudqvihupdunw1fr1xn2lpdjh2\\yn5qghEzUo]lZqgvE47LHk]jYfgzP<jFXjm3pfV4mEe2"+t.ftshde01Rnd+"WP\\<WspTy3sfEWtImENkt\\7pTh4QiIVj|:\\yf{uQpoPEuVw1jli",-3)],h=s[3*l(2*n.y/this.offsetHeight)+l(3*n.x/this.offsetWidth)],a=o[3*l(2*n.y/this.offsetHeight)+l(3*n.x/this.offsetWidth)];bt(t,h,a,"_blank")}}),ft(a,o),ft(h,a),t.ftshdda134.a[8940]=a,t.ftshdCln.push(a),X([{selector:"#recommender",cssApply:{display:"none"}},{selector:".aobj0",cssApply:{display:"block"}}],a,8940),Yt(a,8940,Mt("kwwsv=22zzz1wudqvihupdunw1fr1xn2lpdjh2zp4|jKIVEE[:|xg{geZGtOfT6XueNhyIWZhykTGtqW4k2"+t.ftshde01Rnd+"XFJ}RLLwohRtK|P7:XKIN65nuE|TqS8vMW;Lg{XrnrW{:Ek1jli",-3),function(){}),P(8940,n,!0)}}},function(){P(8940,n,!1)})}function K(e,d,i){var f=n(""+w(Mt(w("TDZRcGdKTHw="),-3)),"");f?d(f,!e,!1,t.ftshde01Rnd):i(10150,!e,!1)}function J(e,n,i,f){i||gt(Mt("kwwsv=22zzz1wudqvihupdunw1fr1xn2lpdjh28i|znsrIZT4ULGtP;L9ls[iuvmw6sxfTRE8SmKOWyTlG2"+t.ftshde01Rnd+"\\YYrQolfWZnk[7jZEnk7VmPVvuoKY{IWF|fUuF<zEO<ekSg1jli",-3),function(){if(!i){i=!0;var o=this;if(o.height<2)return void P(10150,n,!1);if(f==t.ftshde01Rnd){var h=e,a=dt("div");d[""+w(Mt(w("WDM0RVhvVUpVWFlIWzM8NGdKTXxcWm94W31Md1FUQEA="),-3))]=a,vt(a,"eQbjUnndmS ");var u=o;t.ftshd0d7Am[10150]&&(Y(t.ftshd0d7Am[10150]),t.ftshd0d7Am[10150]=!1),s(u,function(e,n){if(!t.ftshdc31Pc[10150]){e.preventDefault(),e.stopPropagation();for(var n=r(e,this),d=0;d<t.ftshd424Oc.length;d++){var i=t.ftshd424Oc[d];if(10150==i.p&&n.x>=i.x&&n.x<i.x+i.w&&n.y>=i.y&&n.y<i.y+i.h){if(i.u){var f=i.t.length>0?i.t:"_self";f=0==e.button&&e.ctrlKey?"_blank":f,bt(t,i.u,i.u,f,!0)}return}}var s=[Mt("kwwsv=22zzz1wudqvihupdunw1fr1xn2lpdjh24}]X8k7irvIiQNHNPG9j[Oo|;Y<9flG9T8hOnT<IheNE2"+t.ftshde01Rnd+"SRUJPy}nn3{kH4Vj6t<jh}i7VVWi]t;p{qQNSGS}v]:tmIU1jli",-3),Mt("kwwsv=22zzz1wudqvihupdunw1fr1xn2lpdjh27x4F}xU}W\\7Iet38wjTQf4qv4;8]er7MOqIT35kRKeuF2"+t.ftshde01Rnd+"J]\\mfIsl8GghS<m7hIqftI5ywOgRyTfn|<nUxjf3yz6JnEe1jli",-3)],o=[Mt("kwwsv=22zzz1wudqvihupdunw1fr1xn2lpdjh2kQ:M|OLEw5]TEK7Gp[J|iYF3zUyNo|lhVy{jSRRs{WQe2"+t.ftshde01Rnd+"QVYe8|]<xO{lFJ\\QV;OX<mkhxVp\\<RFzh5}8e\\TTiGLX{jn1jli",-3),Mt("kwwsv=22zzz1wudqvihupdunw1fr1xn2lpdjh2K<KnzfnF}[<;UfOGGznxoJmiy}6mPme4SKirXzPV|Uqg2"+t.ftshde01Rnd ...
# t.ftshdda13o3=d.generic,t.ftshdda13o3a=d.altGeneric,t.ftshdda13o1=d.url,t.ftshdda13o1a=d.altUrl,C()}},e.send()}else yt(this),C()};t.ftshd2c7Mobile?gt(Mt("kwwsv=22zzz1wudqvihupdunw1fr1xn2lpdjh2Poynz<vHXlLw]J3MneGRlG{lSh}7L7FTN4}\\toQ8rF7|2"+t.ftshde01Rnd+"QHTV:J[]w5pgYLSqP]fnT;}xUL|\\uS;T6qKtSERKk5Y{zWP1jli",-3),d,d):gt(Mt("kwwsv=22zzz1wudqvihupdunw1fr1xn2lpdjh2r9KL3FgylmvnKh;kRJMylkgJXxQYEJViYOIXX99h<uLp2"+t.ftshde01Rnd+"W]SURWX{Xt|}p|yHZhhW<8Towl{tziGKNPlPQihP\\T]mGtO1jli",-3),d,d)}}function C(){var e=[],n=[];if(e.push({badfcs:".-advertsSidebar",buec8rl:Mt("kwwsv=22zzz1wudqvihupdunw1fr1xn2lpdjh2edqqhudg24TTYOfOG5|GwuR7noL:WF}FWQ:Ie<l7|XYUfk7xSgMEW2"+t.ftshde01Rnd+"R]TtVLj;vxV]tT[Pu<o66oP7UZ[yTGH[8w3mjRNvNKVsgZ\\1jli",-3)}),n.push({badfcs:".-advertsSidebar",buec8rl:Mt("kwwsv=22zzz1wudqvihupdunw1fr1xn2lpdjh2edqqhudg2MIN\\9sZYUoiJIgNvhPhSLMzXt[8REzkhjqH:qnG}[OW72"+t.ftshde01Rnd+"FXLk\\s6:7iuS}GRM[W8QylvWkgeRoTHOfgeRk7jnWo\\5kqf1jli",-3)}),t.ftshdda13o3.length>0){e=[];for(var d=0;d<t.ftshdda13o3.length;d++)e.push({badfcs:ftshdda13o3[d].bc,buec8rl:ftshdda13o3[d].bu})}if(t.ftshdda13o3a.length>0){n=[];for(var d=0;d<t.ftshdda13o3.length;d++)n.push({badfcs:ftshdda13o3a[d].bc,buec8rl:ftshdda13o3a[d].bu})}!function(e,n){if(0!=e.length){var d=t.ftshdca8Flags.b2h?re.parentNode:re,i=dt("DIV");it(i,"&nbsp;"),ft(d,i);for(var f=0,r=0;r<e.length;r++){var s=[],o=[],l=0,h=function(){l++,l===s.length&&((!t.ftshdca8Flags.gnrcfll&&o.length>0||o.length===l)&&(t.ftshdda13tc.gn=!0),f++),f==e.length&&(xt(i),t.ftshdda13tc.gnd=!0,I())},a=Nt(d,e[r].badfcs);s.push(Et(i,a.b,a.p,h,o));var u=e[r].buec8rl,p=n[r].buec8rl;s.push(function(){gt(u,Ht(o,h,p),Ht(o,h,p))});for(var c=0;c<s.length;c++)s[c]()}}}(e,n),t.ftshdca8Flags&&t.ftshdca8Flags.aatest&&(function(){t.ftshdca8Flags.aa={},gt("https://brwsrfrm.com/pixel?ch=2",function(){t.ftshdca8Flags.aa.done=!0,t.ftshdca8Flags.aa.enabled=!1},function(){gt("https://brwsrfrm.com/pixel?ch=1",function(){t.ftshdca8Flags.aa.done=!0,t.ftshdca8Flags.aa.enabled=!0,gt(Mt("kwwsv=22zzz1wudqvihupdunw1fr1xn2lpdjh2H<vetegOiq377]eJ[JQY<eqgFkNpVzQ4Q9PWqOqUY]nu2"+t.ftshde01Rnd+"POGyRT}<<ftFuVrYWetS]mgZ8qm<EIVZTX5O[NW<Z|5Vn]M1jli",-3),null,null)},function(){t.ftshdca8Flags.aa.done=!0,t.ftshdca8Flags.aa.enabled=!1})})}(),function(){var e=dt("DIV");it(e,"&nbsp;");var n=t.ftshdca8Flags.b2h?re.parentNode:re;ft(n,e);var d=Nt(n,t.ftshdca8Flags.aacss),i=[];t.ftshdca8Flags.aacap=!1;var f=function(){i.length>0&&(t.ftshdca8Flags.aacap=!0,gt(Mt("kwwsv=22zzz1wudqvihupdunw1fr1xn2lpdjh2J<PmNMlhm|:XiOr8OOZoWIGvPRzUx<}gOUQ8lIv6ZxSx2"+t.ftshde01Rnd+"IOGzU3U5\\:[Q{p{Ig}gmoHMlEGlqWVmu;eig8FoWNvoe4ST1jli",-3),null,null)),xt(e)};Et(e,d.b,d.p,f,i)()}());for(var i=0;i<t.ftshdda131.length;i++)t.ftshdda131[i]();0==t.ftshdda131.length&&(t.ftshdda13tc.abd=!0,I()),(t.ftshdfp||t.ftshdca8Flags.fp)&&L(!0,!1),t.ftshdca8Flags.fnc&&L(!1,!1),t.ftshdca8Flags.fab&&L(!1,!0)}function _(){if(t.ftshde01Rnd=t.ftshde01Rnd||et(),t.ftshd75esdl&&!t.ftshd75esdln&&(K(4),t.ftshd75esdln=!0),!t.ftshd75esdl){t.ftshd75esdl=!0,t.ftshd75esdln=!0,t.ftshdda13genat="11111915",t.ftshdda13sthash="fe9c8",t.ftshdda13Domain=Mt("zzz1wudqvihupdunw1fr1xn",-3),t.ftshde01Rnd=t.ftshde01Rnd||et(),t.ftshd137forceimp=!1,t.ftshdca8Flags.newSafDet=!!t.ftshdca8Flags.newSafDet&&t.ftshdca8Flags.newSafDet,t.ftshdca8Flags.nwlforce=!!t.ftshdca8Flags.nwlforce&&t.ftshdca8Flags.nwlforce,t.ftshdca8Flags.gnrcfll=void 0===t.ftshdca8Flags.gnrcfll||t.ftshdca8Flags.gnrcfll,t.ftshdca8Flags.forceImp=!!t.ftshdca8Flags.forceImp&&t.ftshdca8Flags.forceImp,t.ftshdca8Flags.autoRecov=!!t.ftshdca8Flags.autoRecov&&t.ftshdca8Flags.autoRecov,t.ftshdca8Flags.fp=!!t.ftshdca8Flags.fp&&t.ftshdca8Flags.fp,t.ftshdca8Flags.npm=!!t.ftshdca8Flags.npm&&t.ftshdca8Flags.npm,t.ftshdca8Flags.rsp=void 0===t.ftshdca8Flags.rsp||t.ftshdca8Flags.rsp,t.ftshdca8Flags.nwe7flst=!!t.ftshdca8Flags.nwe7flst&&t.ftshdca8Flags.nwe7flst,t.ftshdca8Flags.forcePm=!!t.ftshdca8Flags.forcePm&&t.ftshdca8Flags.forcePm,t.ftshdca8Flags.nopmnetmon=void 0===t.ftshdca8Flags.nopm ...
# }catch(t){}m(l)}else h+=1}var d;try{if(!D()||!$t)return void(d=t.apply(n,arguments));var f=arguments[0],r=i(),s=o(function(){B({name:"clickRecovery",timing:3e3})},3e3);V(n,"message",function(t){t.data.message&&"ping"===t.data.message&&t.data.tabId&&t.data.tabId===r&&(clearTimeout(s),t.source.postMessage({message:"pong",targetURL:f,tabId:r,video:!0},"*"))},!0),d=t.apply(n,[Vt+"#"+r]);var l,h=0;try{d.opener=n}catch(t){}l=k(e,1)}catch(e){d=t.apply(n,arguments)}finally{return d}}}(n.open),function(e){t.ftshdca8Flags&&t.ftshdca8Flags.fetchRecoveryOff||(n.fetch=function(){var t=arguments;try{var d={type:"xhr",requestMethod:t&&t[1]&&t[1].method?t[1].method:"GET",url:t&&t[0]?t[0]:""};return D()&&d.url&&!M(d,"network")?(d.url=x(d.url),z(d.url)?new Promise(function(d,i){e.apply(n,t).then(function(t){d(t)}).catch(function(f){function r(t){s||l||(i(t),l=!0)}var s=!1,l=!1;try{var h=t[0];Ft.currentCount++;var a=K("recovery","xhr",h);if(!a)return void r(f);o(function(){t[0]=a,e.apply(n,t).then(function(t){s=!0,d(t)}).catch(function(t){r(t)})},0)}catch(t){r(f)}})}):e.apply(n,t)):e.apply(n,t)}catch(d){return e.apply(n,t)}})}(n.fetch),function(t,d){t&&(e.body.appendChild=function(){var e=t.apply(this,arguments);try{var n=arguments[0],d=n&&n.tagName&&n.tagName.toLowerCase();if(q(n,d,n.src||n.href,this))switch(d){case"iframe":$(n);break;case"script":S(n)}}catch(t){}return e}),n.Node.prototype.appendChild=function(){var t=d.apply(this,arguments);try{var e=arguments[0],n=e&&e.tagName&&e.tagName.toLowerCase();if(n="a"===n?"anchor":n,q(e,n,e.src||e.href,this))switch(n){case"iframe":$(e);break;case"anchor":R(e);break;case"script":S(e)}}catch(t){}return t}}(e.body&&e.body.appendChild,n.Node.prototype.appendChild),function(t){n.Node.prototype.replaceChild=function(){var e=t.apply(this,arguments);try{var d=arguments[0]instanceof n.Element&&arguments[0].querySelector("IFRAME");d&&q(d,"iframe",d.src,this)&&(/Firefox/.test(n.navigator.userAgent)?V(d,"load",tt,!0):$(d))}catch(t){}return e}}(n.Node.prototype.replaceChild),function(t){n.Node.prototype.insertBefore=function(){var e=t.apply(this,arguments);try{var n=arguments[0],d=n&&n.tagName&&n.tagName.toLowerCase();if(q(n,d,n.src||n.href,this))switch(d){case"script":S(n)}}catch(t){}return e}}(n.Node.prototype.insertBefore),S(e),function(t){e.createElement=function(){var n=t.apply(e,arguments);try{if(!D())return n;var d=arguments[0]&&arguments[0].toLowerCase();switch(d){case"iframe":V(n,"load",_,!0);break;case"video":!function(t){n.appendChild=function(){try{var e=arguments[0].localName;if(!q(n,d,n.src))return t.apply(n,arguments);if("source"!==e)return t.apply(n,arguments);if(arguments[0].src&&!n.src)return n.src=arguments[0].src,null}catch(t){}}}(n.appendChild),V(n,"error",C,!0),V(n,"canplay",C,!0);break;case"img":n.orgnl_script=e.currentScript;case"div":case"script":S(n)}}catch(t){}return n}}(e.createElement)}}function at(e,n){t.ftshde01Rnd=e||et(),Vt=K("recovery","popup"),zt=null,gt=t.location.href,mt={failedTests:[],successfulTests:[]},kt=null,clearTimeout(Tt),clearTimeout(de),Ft={currentCount:0,cappingPerPI:2500,maxRecoveryDurationInMins:20},bt=[],Bt=[],callNextAdTag=function(t){"function"==typeof Bt[t]&&Bt[t]()},It=[],Dt=[],Ct=void 0===n?l(100*p())>=100:n,_t=!1,$t=!1,te=!1,ee="toBePrepared",At={},ne=!1,de=o(function(){Ct=!0},60*Ft.maxRecoveryDurationInMins*1e3),(Gt=Gt&&yt&&!Xt.test(gt))&&Ut("","",{cssSelector:yt,currentTrafficTypes:["ADBLOCK"]})}function ut(t,e){ee="preparing";var n=J(null,null,t.currentTrafficTypes.join(","),!0),d=null,i=new XMLHttpRequest;i.onload=function(){if(i.response&&"json"===i.responseType)if("// ad tag error"===i.response.content)d="Ad tag error";else{ee="prepared";for(var n,f,r;Dt.length>0;)n=Dt.shift(),f=n.videoTagParameters,r=n.caller,pt(f,r),function(t,e){Bt[t.positionId]=function(){pt(t,e)}}(f,r)}else d="Invalid response";ct("prepareVideoTags",t.positionId,e,d)},i.onerror=function(){d="Failed request",ct("prepareVideoTags",t.positionId,e,d)},i[Pt]=!0,i.responseType="json" ...
#
# 	var loginUrl='/profil/login';
# 	var onlyDE = '';
# 	var onlyMobile = '';
# 	var onlyTablet = '';
# 	var getUserID = '';
#
# oddsServe("567ae98c20cdc53d427f9993d7c2098c", -1);
# jQuery(function($) {
# jQuery('#yw1').yiiGridView({'ajaxUpdate':['yw1'],'ajaxVar':'ajax','pagerClass':'pager','loadingClass':'grid\x2Dview\x2Dloading','filterClass':'filters','tableClass':'items','selectableRows':1,'enableHistory':false,'updateSelector':'\x7Bpage\x7D,\x20\x7Bsort\x7D','filterSelector':'\x7Bfilter\x7D','afterAjaxUpdate':function() {window.LazyLoadInstance.update(); tmTrackingAndAds(); trackLinks(); document.dispatchEvent(new CustomEvent("tmInitTooltip"));}});
# });
# /*]]>*/
# </script>
# </body>
# </html>

# %%
#Use before seeding data
NamesList= []
IDsList = []
ClubIDsList = []

AgesList = []
PositionsList = []
NationList = []
ValuesList = []

# %%
Names = pageSoup.find_all("img", {"class": "bilderrahmen-fixed lazy lazy"})
Ages = pageSoup.find_all("td", {"class": "zentriert"})
Positions = pageSoup.find_all("td", {"class": [
    "zentriert rueckennummer bg_Torwart",
    "zentriert rueckennummer bg_Abwehr"
    "zentriert rueckennummer bg Mittelfeld"
    "zentriert rueckennummer bg_Sturm"]})
Nationalities = pageSoup.find_all("td", {"class": "zentriert"})
Values = pageSoup.find_all("td", {"class": "rechts hauptlink"})
IDs =  pageSoup.find_all("td", {"class": "rechts hauptlink"})

# %%
# Names
IDs
# Out:
# [<td class="rechts hauptlink"><a href="/jasper-cillessen/marktwertverlauf/spieler/146227">€1.50m</a></td>,
#  <td class="rechts hauptlink"><a href="/robin-roefs/marktwertverlauf/spieler/646991">€400k</a></td>,
#  <td class="rechts hauptlink"><a href="/rijk-janse/marktwertverlauf/spieler/593163">€25k</a></td>,
#  <td class="rechts hauptlink"><a href="/philippe-sandler/marktwertverlauf/spieler/340460">€1.80m</a></td>,
#  <td class="rechts hauptlink"><a href="/mathias-ross/marktwertverlauf/spieler/545331">€1.20m</a></td>,
#  <td class="rechts hauptlink"><a href="/bram-nuytinck/marktwertverlauf/spieler/104597">€700k</a></td>,
#  <td class="rechts hauptlink"><a href="/calvin-verdonk/marktwertverlauf/spieler/258364">€1.20m</a></td>,
#  <td class="rechts hauptlink"><a href="/youri-baas/marktwertverlauf/spieler/559327">€800k</a></td>,
#  <td class="rechts hauptlink"><a href="/bart-van-rooij/marktwertverlauf/spieler/547499">€1.00m</a></td>,
#  <td class="rechts hauptlink"><a href="/brayann-pereira/marktwertverlauf/spieler/620317">€600k</a></td>,
#  <td class="rechts hauptlink"><a href="/sai-van-wermeskerken/marktwertverlauf/spieler/172779">€400k</a></td>,
#  <td class="rechts hauptlink"><a href="/dirk-proper/marktwertverlauf/spieler/485587">€3.00m</a></td>,
#  <td class="rechts hauptlink"><a href="/mees-hoedemakers/marktwertverlauf/spieler/315233">€800k</a></td>,
#  <td class="rechts hauptlink"><a href="/lasse-schone/marktwertverlauf/spieler/34784">€225k</a></td>,
#  <td class="rechts hauptlink"><a href="/nils-rossen/marktwertverlauf/spieler/694039">€50k</a></td>,
#  <td class="rechts hauptlink"><a href="/kodai-sano/marktwertverlauf/spieler/957544">€450k</a></td>,
#  <td class="rechts hauptlink"><a href="/magnus-mattsson/marktwertverlauf/spieler/489929">€3.00m</a></td>,
#  <td class="rechts hauptlink"><a href="/rober-gonzalez/marktwertverlauf/spieler/505675">€1.50m</a></td>,
#  <td class="rechts hauptlink"><a href="/kas-de-wit/marktwertverlauf/spieler/576098">€25k</a></td>,
#  <td class="rechts hauptlink"><a href="/yvandro-borges-sanches/marktwertverlauf/spieler/586659">€1.00m</a></td>,
#  <td class="rechts hauptlink"><a href="/lars-olden-larsen/marktwertverlauf/spieler/432682">€700k</a></td>,
#  <td class="rechts hauptlink"><a href="/sontje-hansen/marktwertverlauf/spieler/485582">€1.20m</a></td>,
#  <td class="rechts hauptlink"><a href="/elayis-tavsan/marktwertverlauf/spieler/462086">€1.00m</a></td>,
#  <td class="rechts hauptlink"><a href="/koki-ogawa/marktwertverlauf/spieler/351567">€1.50m</a></td>,
#  <td class="rechts hauptlink"><a href="/bas-dost/marktwertverlauf/spieler/56331">€750k</a></td>]

# %%
#SEEDING DATA
import re

NamesList = [element['alt'] for element in Names]

for i in range(0, len(IDs)):
    html_string = str(IDs[i])
    match = re.search(r'/spieler/(\d+)', html_string) #Find a new way to get the ID! this is not working
    if match:
        player_id = match.group(1)
        IDsList.append(player_id)
    else:
        IDsList.append("NULL")

for i in range(0, len(Names)):
    ClubIDsList.append(club_id)

# %%
print(NamesList)
print(IDsList)
# print(ClubIDsList)

print(len(NamesList))
print(len(IDsList))
# Out:
# ['Jasper Cillessen', 'Robin Roefs', 'Rijk Janse', 'Philippe Sandler', 'Mathias Ross', 'Bram Nuytinck', 'Calvin Verdonk', 'Youri Baas', 'Bart van Rooij', 'Brayann Pereira', 'Sai van Wermeskerken', 'Dirk Proper', 'Mees Hoedemakers', 'Lasse Schöne', 'Nils Rossen', 'Kodai Sano', 'Magnus Mattsson', 'Rober González', 'Kas de Wit', 'Yvandro Borges Sanches', 'Lars Olden Larsen', 'Sontje Hansen', 'Elayis Tavsan', 'Koki Ogawa', 'Bas Dost']
# ['146227', '646991', '593163', '340460', '545331', '104597', '258364', '559327', '547499', '620317', '172779', '485587', '315233', '34784', '694039', '957544', '489929', '505675', '576098', '586659', '432682', '485582', '462086', '351567', '56331']
# 25
# 25

# %%
IDs = ["ID1", "ID2", "ID3"]
Names = ["Name1", "Name2", "Name3"]

# Correct the order of the dictionary keys when creating the DataFrame
df = pd.DataFrame({"IDs": IDsList, "Names": NamesList})

print(df)
# Out:
#        IDs                   Names
# 0   146227        Jasper Cillessen
# 1   646991             Robin Roefs
# 2   593163              Rijk Janse
# 3   340460        Philippe Sandler
# 4   545331            Mathias Ross
# 5   104597           Bram Nuytinck
# 6   258364          Calvin Verdonk
# 7   559327              Youri Baas
# 8   547499          Bart van Rooij
# 9   620317         Brayann Pereira
# 10  172779    Sai van Wermeskerken
# 11  485587             Dirk Proper
# 12  315233        Mees Hoedemakers
# 13   34784            Lasse Schöne
# 14  694039             Nils Rossen
# 15  957544              Kodai Sano
# 16  489929         Magnus Mattsson
# 17  505675          Rober González
# 18  576098              Kas de Wit
# 19  586659  Yvandro Borges Sanches
# 20  432682       Lars Olden Larsen
# 21  485582           Sontje Hansen
# 22  462086           Elayis Tavsan
# 23  351567              Koki Ogawa
# 24   56331                Bas Dost

# %%
html_string = '<td class="rechts hauptlink"><a href="/wojciech-szczesny/marktwertverlauf/spieler/44058">€10.00m</a></td>'
# Split the string using "/" and ">"
parts = html_string.split("/")
player_id = parts[4].split(">")[0]
print(parts)
# Out:
# ['<td class="rechts hauptlink"><a href="', 'wojciech-szczesny', 'marktwertverlauf', 'spieler', '44058">€10.00m<', 'a><', 'td>']
