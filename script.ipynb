# %% [markdown]
# Make sure that
# * sudo pip3 install requests
# * sudo pip3 install bs4
# * sudo pip3 install pandas
#
# were ran before executing the code beneath

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux ×86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.106 Safari/537.36'}
page =  "https://www.transfermarkt.co.uk/fc-arsenal/startseite/verein/31"
pageTree = requests.get(page, headers=headers)
pageSoup = BeautifulSoup(pageTree. content, 'html.parser')

# %%
club_id = page.split("/")[-1]
print(club_id)
# Out:
# 31

# %%
pageSoup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <script data-description="sourcepoint stub code" type="text/javascript">
# ...

# %%
#Use before seeding data
NamesList= []
IDsList = []
ClubIDsList = []

AgesList = []
PositionsList = []
NationList = []
ValuesList = []

# %%
Names = pageSoup.find_all("img", {"class": "bilderrahmen-fixed lazy lazy"})
Ages = pageSoup.find_all("td", {"class": "zentriert"})
Positions = pageSoup.find_all("td", {"class": [
    "zentriert rueckennummer bg_Torwart",
    "zentriert rueckennummer bg_Abwehr"
    "zentriert rueckennummer bg Mittelfeld"
    "zentriert rueckennummer bg_Sturm"]})
Nationalities = pageSoup.find_all("td", {"class": "zentriert"})
Values = pageSoup.find_all("td", {"class": "rechts hauptlink"})
IDs =  pageSoup.find_all("td", {"class": "rechts hauptlink"})

# %%
Names
IDs

# %%
#SEEDING DATA
import re

NamesList = [element['alt'] for element in Names]

for i in range(0, len(IDs)):
    html_string = str(IDs[i])
    match = re.search(r'/spieler/(\d+)', html_string) #Find a new way to get the ID! this is not working
    if match:
        player_id = match.group(1)
        IDsList.append(player_id)
    else:
        IDsList.append("NULL")

for i in range(0, len(Names)):
    ClubIDsList.append(club_id)

# %%
print(NamesList)
print(IDsList)
# print(ClubIDsList)

print(len(NamesList))
print(len(IDsList))
# Out:
# ['Alisson', 'Caoimhín Kelleher', 'Adrián', 'Ibrahima Konaté', 'Virgil van Dijk', 'Joe Gomez', 'Joel Matip', 'Jarell Quansah', 'Andrew Robertson', 'Konstantinos Tsimikas', 'Trent Alexander-Arnold', 'Conor Bradley', 'Wataru Endo', 'Stefan Bajcetic', 'Dominik Szoboszlai', 'Alexis Mac Allister', 'Ryan Gravenberch', 'Curtis Jones', 'Thiago', 'Harvey Elliott', 'Luis Díaz', 'Diogo Jota', 'Mohamed Salah', 'Ben Doak', 'Darwin Núñez', 'Cody Gakpo']
# ...

# %%
test = ['234509', '336077', '34130', '480762', '164770', '177907', '184573', '42412', '183288', '339340', '282429', '357147', '477758', '16306', '287579', '315969', '288255', '820374', '240306', '346483', '69633', '607224', '640026', '258923', '401173', '811779', '602105', '536835', '676318', '610442', '182877', '234509', '336077', '34130', '480762', '164770', '177907', '184573', '42412', '183288', '339340', '282429', '357147', '477758', '16306', '287579', '315969', '288255', '820374', '240306', '346483', '69633', '607224', '640026', '258923', '401173', '811779', '602105', '536835', '676318', '610442', '182877']
print(len(test))
test2 = ['234509', '336077', '34130', '480762', '164770', '177907', '184573', '42412', '183288', '339340', '282429', '357147', '477758', '16306', '287579', '315969', '288255', '820374', '240306', '346483', '69633', '607224', '640026', '258923', '401173', '811779', '602105', '536835', '676318', '610442', '182877', '234509', '336077', '34130', '480762', '164770', '177907', '184573', '42412', '183288', '339340', '282429', '357147', '477758', '16306', '287579', '315969', '288255', '820374', '240306', '346483', '69633', '607224', '640026', '258923', '401173', '811779', '602105', '536835', '676318', '610442', '182877', '234509', '336077', '34130', '480762', '164770', '177907', '184573', '42412', '183288', '339340', '282429', '357147', '477758', '16306', '287579', '315969', '288255', '820374', '240306', '346483', '69633', '607224', '640026', '258923', '401173', '811779', '602105', '536835', '676318', '610442', '182877', '234509', '336077', '34130', '480762', '164770', '177907', '184573', '42412', '183288', '339340', '282429', '357147', '477758', '16306', '287579', '315969', '288255', '820374', '240306', '346483', '69633', '607224', '640026', '258923', '401173', '811779', '602105', '536835', '676318', '610442', '182877', '234509', '336077', '34130', '480762', '164770', '177907', '184573', '42412', '183288', '339340', '282429', '357147', '477758', '16306', '287579', '315969', '288255', '820374', '240306', '346483', '69633', '607224', '640026', '258923', '401173', '811779', '602105', '536835', '676318', '610442', '182877']

for i in test:
    if i in test2:
        print("True")
# Out:
# 62
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
