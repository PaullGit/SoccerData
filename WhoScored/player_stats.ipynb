# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
player = 315227 #Erling Haaland

# %%
season = []
team = []
tournament = []
apps = []
mins = []
goals = []
assist = []
yellow = []
red = []
spg = []
ps_percent = []
aerials_won = []
motm = []
rating = []

# %%
headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux ×86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.106 Safari/537.36'}

# %%
page =  f"https://www.whoscored.com/Players/315227/History/Erling-Haaland"
pageTree = requests.get(page, headers=headers)
pageSoup = BeautifulSoup(pageTree. content, 'html.parser')

# %%
pageSoup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <link href="https://d2zywfiolv4f83.cloudfront.net/" rel="dns-prefetch"/>
# <link crossorigin="" href="https://d2zywfiolv4f83.cloudfront.net/" rel="preconnect"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="app-id=940048063" name="apple-itunes-app"/>
# <!-- #10 -->
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# ...

# %%
# test = (pageSoup.find_all("div", {"id": "statistics-table-summary"}))
test = pageSoup.find_all("td")
print(test) #<td class="col12-lg-1 col12-m-1 col12-s-2 col12-xs-2 grid-abs overflow-text">2018/2019</td>
# Out:
# []
